# %% [markdown]
# <a href="https://colab.research.google.com/github/jvviercttlan/si/blob/main/pss.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s = "Hola Mundo"
print(s)
# Out:
# Hola Mundo
